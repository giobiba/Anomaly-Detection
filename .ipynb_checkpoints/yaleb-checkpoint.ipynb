# %%
from anomalydetection.rpca import rpca
from anomalydetection.RDAE import RDAE
from anomalydetection.utils.utils import l1shrink
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from anomalydetection.utils.utils import fnorm
from PIL import Image
import gc
import os
import itertools
from sklearn.decomposition import PCA
import cv2
from sklearn.preprocessing import MinMaxScaler

# %%
# without resize
images = [file for file in os.listdir('./data/yaleB38') if file.endswith('pgm')]
temp = []
for image_name in images:
    img = mpimg.imread('./data/yaleB38/' + image_name) 
    img = img.reshape(img.size)
    temp.append(img)
data = np.array(temp)

# %%
# with resize
images = [file for file in os.listdir('./data/yaleB38') if file.endswith('pgm')]
temp = []
for image_name in images:
    img = cv2.imread('./data/yaleB38/' + image_name, cv2.IMREAD_GRAYSCALE)
    
    img = cv2.resize(img,(84, 96),cv2.INTER_AREA)
    img = img.flatten()
    temp.append(img)
data = np.array(temp)

# %%
l_costs = []
LS = []

lambdas=[0.0005, 0.002, 0.003, 0.007, 0.010, 0.03]

noise = np.linalg.norm(data - data[0], axis=1)
for l in lambdas[1:]:
    model = rpca(verbose=False, lambda_=l, max_iter=500)
    L, S = model.fit_transform(data)
    
    costs = np.linalg.norm(L - data[0], axis=1) / noise
    l_costs.append(costs)
    LS.append(L)
    print(costs)
# Out:
# C:\Users\gblan\AppData\Local\Temp\ipykernel_16696\4084857631.py:11: RuntimeWarning: divide by zero encountered in divide
#   costs = np.linalg.norm(L - data[0], axis=1) / noise
# [            inf 7.30824658e+126 4.61697452e+126 4.63995436e+126
#  3.97435668e+126 3.67911935e+126 4.91862876e+126 4.16277805e+126
#  6.57504710e+126 4.30389365e+126 6.56995668e+126 1.05771161e+127
#  5.11743035e+126 3.79143882e+126 6.28276149e+126 7.50238896e+126
#  6.60646464e+126 7.18156095e+126 7.09701489e+126 6.29807079e+126
#  5.52908343e+126 5.42430933e+126 8.20845636e+126 7.69288380e+126
#  6.89161585e+126 5.38333019e+126 5.20564070e+126 4.39336616e+126
#  4.50159738e+126 4.81721792e+126 6.60238257e+126 4.76995630e+126
#  4.73335597e+126 4.81030885e+126 7.55996623e+126 4.90986503e+126
#  6.25719640e+126 6.60250708e+126 4.83908884e+126 7.05516652e+126
#  6.79831378e+126 4.78063461e+126 5.74676427e+126 5.37621878e+126
#  5.43205701e+126 4.55538310e+126 4.46523501e+126 4.94183417e+126
#  6.64264520e+126 4.43178003e+126 3.95434950e+126 5.02448735e+126
#  4.47639017e+126 4.81829164e+126 4.74437989e+126 5.61478687e+126
#  4.37329686e+126 5.02877162e+126 5.39250059e+126 6.47688418e+126
#  4.68041227e+126 5.75635198e+126 5.09146284e+126 5.49153830e+126]
# [            inf 1.28059228e+127 1.51490644e+127 1.86395799e+127
#  1.74066572e+127 1.53223855e+127 1.77811179e+127 2.05642561e+127
#  2.40664818e+127 2.22383964e+127 2.64195047e+127 2.98576799e+127
#  1.80336438e+127 1.59205879e+127 1.96183541e+127 2.16212319e+127
#  1.96006856e+127 2.39813173e+127 2.72899018e+127 2.42531035e+127
#  1.84865454e+127 1.76313381e+127 2.32065630e+127 2.76209068e+127
#  2.49088650e+127 1.93244944e+127 2.43890385e+127 1.79982015e+127
#  1.48185378e+127 1.75888437e+127 2.16902859e+127 1.66002981e+127
#  1.67365109e+127 1.50792032e+127 1.26592857e+127 1.58029361e+127
#  2.41250935e+127 2.36677231e+127 2.61250399e+127 2.58641834e+127
#  2.37157040e+127 1.74248177e+127 2.23945706e+127 2.47079676e+127
#  2.42827450e+127 1.83419599e+127 1.65452398e+127 1.94154437e+127
#  2.77540279e+127 1.90525571e+127 1.42468553e+127 2.90250784e+127
#  2.01390918e+127 2.28689797e+127 1.72349827e+127 1.57270386e+127
#  1.82458542e+127 2.78604593e+127 1.70786073e+127 2.06710564e+127
#  3.11355035e+127 1.93529079e+127 2.61913503e+127 1.29732042e+127]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [106], in <cell line: 7>()
#       7 for l in lambdas:
#       8     model = rpca(verbose=False, lambda_=l, max_iter=500)
# ----> 9     L, S = model.fit_transform(data)
#      11     costs = np.linalg.norm(L - data[0], axis=1) / noise
#      12     l_costs.append(costs)
#
# File ~\Desktop\restored\anomalydetection\rpca.py:122, in rpca.fit_transform(self, x)
#     118 Y += (xt - S - L)* self.mu_
#     120 primal, dual = self._calculate_residuals(xt, S, L, S_old)
# --> 122 primal_tol, dual_tol = self._update_tols(xt, S, L, Y)
#     123 eps_primal = np.sqrt(m) * self.ABS_TOL + primal_tol
#     124 eps_dual = np.sqrt(m) * self.ABS_TOL + dual_tol
#
# File ~\Desktop\restored\anomalydetection\rpca.py:71, in rpca._update_tols(self, x, S, L, Y)
#      69 def _update_tols(self, x, S, L, Y):
#      70     primal_tol = self.REL_TOL * max(l2norm(x), l2norm(S), l2norm(L))
# ---> 71     dual_tol = self.REL_TOL * l2norm(Y)
#      72     return primal_tol, dual_tol
#
# File ~\Desktop\restored\anomalydetection\utils\utils.py:21, in l2norm(x)
#      20 def l2norm(x):
# ---> 21     return np.linalg.norm(x, ord=2)
#
# File <__array_function__ internals>:180, in norm(*args, **kwargs)
#
# File c:\users\gblan\desktop\restored\venv\lib\site-packages\numpy\linalg\linalg.py:2575, in norm(x, ord, axis, keepdims)
#    2573     raise ValueError('Duplicate axes given.')
#    2574 if ord == 2:
# -> 2575     ret =  _multi_svd_norm(x, row_axis, col_axis, amax)
#    2576 elif ord == -2:
#    2577     ret = _multi_svd_norm(x, row_axis, col_axis, amin)
#
# File c:\users\gblan\desktop\restored\venv\lib\site-packages\numpy\linalg\linalg.py:2349, in _multi_svd_norm(x, row_axis, col_axis, op)
#    2326 """Compute a function of the singular values of the 2-D matrices in `x`.
#    2327
#    2328 This is a private utility function used by `numpy.linalg.norm()`.
#    (...)
#    2346
#    2347 """
#    2348 y = moveaxis(x, (row_axis, col_axis), (-2, -1))
# -> 2349 result = op(svd(y, compute_uv=False), axis=-1)
#    2350 return result
#
# File <__array_function__ internals>:180, in svd(*args, **kwargs)
#
# File c:\users\gblan\desktop\restored\venv\lib\site-packages\numpy\linalg\linalg.py:1670, in svd(a, full_matrices, compute_uv, hermitian)
#    1668 signature = 'D->d' if isComplexType(t) else 'd->d'
#    1669 s = gufunc(a, signature=signature, extobj=extobj)
# -> 1670 s = s.astype(_realType(result_t), copy=False)
#    1671 return s
#
# KeyboardInterrupt:

# %%
tests = []
l_costs_pca = []
ncs = [1, 2, 3, 4, 5, 7, 9, 11, 64]
noise = np.linalg.norm(data - data[0], axis=1)
for nc in ncs:
    pca = PCA(n_components=nc, svd_solver='full')
    pca.fit_transform(data)

    x_redused = np.dot(data - pca.mean_, pca.components_.T)
    x_inversed = np.dot(x_redused, pca.components_) + pca.mean_
    
    tests.append(x_inversed)
    p_costs = np.linalg.norm(x_inversed - data[0], axis=1) / noise
    p_costs[0] = 0
    l_costs_pca.append(p_costs[1:])
# Out:
# C:\Users\gblan\AppData\Local\Temp\ipykernel_16696\1222746051.py:13: RuntimeWarning: divide by zero encountered in divide
#   p_costs = np.linalg.norm(x_inversed - data[0], axis=1) / noise
# C:\Users\gblan\AppData\Local\Temp\ipykernel_16696\1222746051.py:13: RuntimeWarning: divide by zero encountered in divide
#   p_costs = np.linalg.norm(x_inversed - data[0], axis=1) / noise
# C:\Users\gblan\AppData\Local\Temp\ipykernel_16696\1222746051.py:13: RuntimeWarning: divide by zero encountered in divide
#   p_costs = np.linalg.norm(x_inversed - data[0], axis=1) / noise
# C:\Users\gblan\AppData\Local\Temp\ipykernel_16696\1222746051.py:13: RuntimeWarning: divide by zero encountered in divide
#   p_costs = np.linalg.norm(x_inversed - data[0], axis=1) / noise
# C:\Users\gblan\AppData\Local\Temp\ipykernel_16696\1222746051.py:13: RuntimeWarning: divide by zero encountered in divide
#   p_costs = np.linalg.norm(x_inversed - data[0], axis=1) / noise
# C:\Users\gblan\AppData\Local\Temp\ipykernel_16696\1222746051.py:13: RuntimeWarning: divide by zero encountered in divide
#   p_costs = np.linalg.norm(x_inversed - data[0], axis=1) / noise
# C:\Users\gblan\AppData\Local\Temp\ipykernel_16696\1222746051.py:13: RuntimeWarning: divide by zero encountered in divide
#   p_costs = np.linalg.norm(x_inversed - data[0], axis=1) / noise
# C:\Users\gblan\AppData\Local\Temp\ipykernel_16696\1222746051.py:13: RuntimeWarning: divide by zero encountered in divide
#   p_costs = np.linalg.norm(x_inversed - data[0], axis=1) / noise
# C:\Users\gblan\AppData\Local\Temp\ipykernel_16696\1222746051.py:13: RuntimeWarning: divide by zero encountered in divide
#   p_costs = np.linalg.norm(x_inversed - data[0], axis=1) / noise

# %%
plt.imshow(tests[0][0].reshape(96, 84), cmap='gray')

# %%
fig, ax = plt.subplots(1, dpi=120)
ax.boxplot(l_costs, lambdas, showfliers=False)
plt.xticks(range(1, len(lambdas)+1), nlambdascs)
plt.xlabel("$\lambda$")
plt.ylabel("Reconstruction error")
plt.show()

# %%
fig, ax = plt.subplots(1, dpi=120)
ax.boxplot(l_costs_pca, ncs, showfliers=False)
plt.xticks(range(1, len(ncs)+1), ncs)
plt.xlabel("$\lambda$")
plt.ylabel("Reconstruction error")
plt.show()

# %%
plt.imshow(data[0].reshape(192, 168), cmap='gray')

# %%
# Out:
# 8

# %%
fig, ax = plt.subplots(4, 4, dpi=1000)
k = 0
for i in [16,21,25,30]:
    t=0
    for j in [0, 1, -1]:
        ax[k][t].imshow(tests[j][i].reshape(192, 168), cmap='gray')
        ax[k][t].xaxis.set_ticklabels([])
        ax[k][t].yaxis.set_ticklabels([])
        t+=1
    ax[k][3].imshow(data[i].reshape(192, 168), cmap='gray')
    ax[k][3].xaxis.set_ticklabels([])
    ax[k][3].yaxis.set_ticklabels([])
    
    k+=1
    
ax[0][0].set_title(f"n_comp={ncs[0]}")
ax[0][1].set_title(f"n_comp={ncs[3]}")
ax[0][2].set_title(f"n_comp={ncs[5]}")


ax[0][3].set_title("Original")
plt.show()

# %%
i = 32
l = 3
ls = LS[l].reshape((64, 192, 168))
ss = SS[l].reshape((64, 192, 168))
dd = data.reshape((64, 192, 168))
fig, ax = plt.subplots(1,3, dpi=80)
plt.subplots_adjust(left=0.1, right=1.3)


ax[0].imshow(dd[i], cmap='gray')
#ax[0].set_title('Original')
ax[1].imshow(ls[i], cmap='gray')
#ax[1].set_title('Low-rank')
ax[2].imshow(ss[i], cmap='gray')
#ax[2].set_title('Sparse')

# %%
ii = [25, 21, 32, 16]
l1 = 5
l2 = 3
out = tests[l1].reshape((64, 192, 168))
ls = LS[l2].reshape((64, 192, 168))
fig, ax = plt.subplots(4,3)
plt.subplots_adjust(right=0.55)

j=0
ax[0][0].set_title('PCA', fontsize=8)
ax[0][1].set_title('RPCA',fontsize=8)
ax[0][2].set_title('Original',fontsize=8)
for i in ii:
    ax[j][0].imshow(out[i], cmap='gray')
    ax[j][0].set_xticks([])
    ax[j][0].set_yticks([])
    ax[j][1].imshow(ls[i], cmap='gray')
    ax[j][1].set_xticks([])
    ax[j][1].set_yticks([])
    ax[j][2].imshow(dd[i], cmap='gray')
    ax[j][2].set_xticks([])
    ax[j][2].set_yticks([])
    j+=1

# %%
rdae_c = []
rdae_l = []
rdae_s = []

scaler = MinMaxScaler()
data1 = scaler.fit_transform(data)

noise = np.linalg.norm(data1 - data1[0], axis=1)
for l in np.linspace(0.001, 0.1, 10): 
    
    model = RDAE(verbose=False, encoder_layer_size=[8064, 4032], decoder_layer_size=[8064], 
                 lambda_=l, dropout=0.0, activation_function='sigmoid')
    model.compile(loss='BCE', optimizer = tf.keras.optimizers.Adam(0.005)) 
    L, S = model.fit_transform(data1, 25, 20, 10)


    costs = np.linalg.norm(L - data1[0], axis=1) / noise
    print(f"Lambda: {l}, cost: {np.mean(costs)}")
    rdae_c.append(costs)
    rdae_l.append(L)
    rdae_s.append(S)
    

    del model
    tf.keras.backend.clear_session()
    gc.collect()
# Out:
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Input In [154], in <cell line: 9>()
#      11 model = RDAE(verbose=False, encoder_layer_size=[8064, 4032], decoder_layer_size=[8064],
#      12              lambda_=l, dropout=0.0, activation_function='sigmoid')
#      13 model.compile(loss='BCE', optimizer = tf.keras.optimizers.Adam(0.005))
# ---> 14 L, S = model.fit_transform(data1, 25, 20, 10)
#      17 costs = np.linalg.norm(L - data1[0], axis=1) / noise
#      18 print(f"Lambda: {l}, cost: {np.mean(costs)}")
#
# File ~\Desktop\restored\anomalydetection\RDAE.py:97, in RDAE.fit_transform(self, x, inner_iteration, outer_iteration, batch_size)
#      94 self.L = x - self.S
#      96 # Train the autoencoder with L
# ---> 97 self.history.append(self.AE.fit(x=self.L, y=self.L,
#      98                            epochs=inner_iteration,
#      99                            batch_size=batch_size,
#     100                            verbose=self.verbose,
#     101                            shuffle=True))
#     102 # get L optimized
#     103 self.L = self.AE.predict(self.L, verbose=self.verbose)
#
# File c:\users\gblan\desktop\restored\venv\lib\site-packages\keras\utils\traceback_utils.py:67, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67   raise e.with_traceback(filtered_tb) from None
#      68 finally:
#      69   del filtered_tb
#
# File c:\users\gblan\desktop\restored\venv\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# ResourceExhaustedError: Graph execution error:
#
# Detected at node 'gradient_tape/dae_1/sequential_3/dense_5/MatMul/MatMul_1' defined at (most recent call last):
#     File "C:\Users\gblan\AppData\Local\Programs\Python\Python39\lib\runpy.py", line 197, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "C:\Users\gblan\AppData\Local\Programs\Python\Python39\lib\runpy.py", line 87, in _run_code
#       exec(code, run_globals)
#     File "c:\users\gblan\desktop\restored\venv\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#       app.launch_new_instance()
#     File "c:\users\gblan\desktop\restored\venv\lib\site-packages\traitlets\config\application.py", line 976, in launch_instance
#       app.start()
#     File "c:\users\gblan\desktop\restored\venv\lib\site-packages\ipykernel\kernelapp.py", line 712, in start
#       self.io_loop.start()
#     File "c:\users\gblan\desktop\restored\venv\lib\site-packages\tornado\platform\asyncio.py", line 215, in start
#       self.asyncio_loop.run_forever()
#     File "C:\Users\gblan\AppData\Local\Programs\Python\Python39\lib\asyncio\base_events.py", line 596, in run_forever
#       self._run_once()
#     File "C:\Users\gblan\AppData\Local\Programs\Python\Python39\lib\asyncio\base_events.py", line 1890, in _run_once
#       handle._run()
#     File "C:\Users\gblan\AppData\Local\Programs\Python\Python39\lib\asyncio\events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "c:\users\gblan\desktop\restored\venv\lib\site-packages\ipykernel\kernelbase.py", line 510, in dispatch_queue
#       await self.process_one()
#     File "c:\users\gblan\desktop\restored\venv\lib\site-packages\ipykernel\kernelbase.py", line 499, in process_one
#       await dispatch(*args)
#     File "c:\users\gblan\desktop\restored\venv\lib\site-packages\ipykernel\kernelbase.py", line 406, in dispatch_shell
#       await result
#     File "c:\users\gblan\desktop\restored\venv\lib\site-packages\ipykernel\kernelbase.py", line 730, in execute_request
#       reply_content = await reply_content
#     File "c:\users\gblan\desktop\restored\venv\lib\site-packages\ipykernel\ipkernel.py", line 383, in do_execute
#       res = shell.run_cell(
#     File "c:\users\gblan\desktop\restored\venv\lib\site-packages\ipykernel\zmqshell.py", line 528, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "c:\users\gblan\desktop\restored\venv\lib\site-packages\IPython\core\interactiveshell.py", line 2881, in run_cell
#       result = self._run_cell(
#     File "c:\users\gblan\desktop\restored\venv\lib\site-packages\IPython\core\interactiveshell.py", line 2936, in _run_cell
#       return runner(coro)
#     File "c:\users\gblan\desktop\restored\venv\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "c:\users\gblan\desktop\restored\venv\lib\site-packages\IPython\core\interactiveshell.py", line 3135, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "c:\users\gblan\desktop\restored\venv\lib\site-packages\IPython\core\interactiveshell.py", line 3338, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "c:\users\gblan\desktop\restored\venv\lib\site-packages\IPython\core\interactiveshell.py", line 3398, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "C:\Users\gblan\AppData\Local\Temp\ipykernel_20912\1750129333.py", line 14, in <cell line: 9>
#       L, S = model.fit_transform(data1, 25, 20, 10)
#     File "C:\Users\gblan\Desktop\restored\anomalydetection\RDAE.py", line 97, in fit_transform
#       self.history.append(self.AE.fit(x=self.L, y=self.L,
#     File "c:\users\gblan\desktop\restored\venv\lib\site-packages\keras\utils\traceback_utils.py", line 64, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\users\gblan\desktop\restored\venv\lib\site-packages\keras\engine\training.py", line 1409, in fit
#       tmp_logs = self.train_function(iterator)
#     File "c:\users\gblan\desktop\restored\venv\lib\site-packages\keras\engine\training.py", line 1051, in train_function
#       return step_function(self, iterator)
#     File "c:\users\gblan\desktop\restored\venv\lib\site-packages\keras\engine\training.py", line 1040, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "c:\users\gblan\desktop\restored\venv\lib\site-packages\keras\engine\training.py", line 1030, in run_step
#       outputs = model.train_step(data)
#     File "c:\users\gblan\desktop\restored\venv\lib\site-packages\keras\engine\training.py", line 893, in train_step
#       self.optimizer.minimize(loss, self.trainable_variables, tape=tape)
#     File "c:\users\gblan\desktop\restored\venv\lib\site-packages\keras\optimizers\optimizer_v2\optimizer_v2.py", line 537, in minimize
#       grads_and_vars = self._compute_gradients(
#     File "c:\users\gblan\desktop\restored\venv\lib\site-packages\keras\optimizers\optimizer_v2\optimizer_v2.py", line 590, in _compute_gradients
#       grads_and_vars = self._get_gradients(tape, loss, var_list, grad_loss)
#     File "c:\users\gblan\desktop\restored\venv\lib\site-packages\keras\optimizers\optimizer_v2\optimizer_v2.py", line 471, in _get_gradients
#       grads = tape.gradient(loss, var_list, grad_loss)
# Node: 'gradient_tape/dae_1/sequential_3/dense_5/MatMul/MatMul_1'
# OOM when allocating tensor with shape[4032,8064] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node gradient_tape/dae_1/sequential_3/dense_5/MatMul/MatMul_1}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [Op:__inference_train_function_790921]

# %%
del model
tf.keras.backend.clear_session()
gc.collect()
# Out:
# 6585

# %%
rdae_c[0]
# Out:
# array([0.52075729, 0.46281078, 0.43226431, ..., 0.39456088, 0.32812542,
#        0.32446209])

# %%
plt.imshow((rdae_l[1][30]).reshape(96,84), cmap='gray')

# %%
plt.imshow(data[0].reshape(96,84), cmap='gray')

# %%
data1[0]
# Out:
# array([0.12941176, 0.13114754, 0.1372549 , ..., 0.40251572, 0.35802469,
#        0.34591195])
